# %% [markdown]
# # Victor Hugo Avila Felipe - A01794425

# %% [markdown]
# ![portada_tec_monterey.png](attachment:portada_tec_monterey.png)

# %% [markdown]
# # Data Analysis with Python
# ## IBM: DA0101EN
#
#
# LEARNING OBJECTIVES
#
# In this course you will learn about:
#
#     Data Acquisition
#     How to Obtain Basic Insight From a Dataset
#     Data Wrangling
#     Exploratory Data Analysis
#     Model Development
#     Model Evaluation

# %% [markdown]
# ## 1 Introduction to Data Analysis with Python
#
# - Problem requiring data analysis
# - dataset to analyze in python
# - overview of packages
# - import and export data
# - Basic insights
#
# Can we estimate the price of used cars?
#
# ### The problem
#
# why data analysis?
# data everywhere, helps discovery of information.
#
# Tom wants to sell his car, but wants the best price.
# what affects the price?
#
# ### Understand the data
#
# There are documentation and the .csv file.
#
# The first attribute, "symboling", corresponds to the insurance risk level of a car.
# Cars are initially assigned a risk factor symbol associated with their price.
# Then, if an automobile is more risky, this symbol is adjusted by moving it up the scale.
# A value of +3 indicates that the auto is risky, -3 that it is probably pretty safe.
# The second attribute "normalized-losses" is the relative average loss payment per insured vehicle year.
# This value is normalized for all autos within a particular size classification (two-door small, station wagons, sports/speciality, etc...), and represents the average loss per car per year.
# The values range from 65 to 256. The other attributes are easy to understand.
#
# ###### Thus, the goal of this project is to predict "price" in terms of other car features.
#
# ![curso1.PNG](attachment:curso1.PNG)

# %% [markdown]
# ### Python packages
#
# A Python library is a collection of functions and methods that allow you to perform lots of actions without writing any code.
# The libraries usually contain built-in modules providing different functionalities, which you can use directly.
# And there are extensive libraries, offering a broad range of facilities.

# %% [markdown]
# ![curso2.PNG](attachment:curso2.PNG)

# %% [markdown]
# ![curso3.PNG](attachment:curso3.PNG)

# %% [markdown]
# ![curso4.PNG](attachment:curso4.PNG)

# %% [markdown]
# ### importing and exporting data
#
# Format and file path.
# read_csv()
# df
# df.head(n)
# df.tail(n)
#
# Add headers
# df.columns = headers
# headers = ["a","b","c"]
#
# export df to csv:
# df.to_csv(path)
#
# csv, json, excel, sql

# %% [markdown]
# ### Analyzing data
#
# Check data type
# data distribution
#
# object, float, int y datatime
#
# - potential info and type mismatch
# - compatibility with python methods
#
# dataframe.dtypes
#
# df.describe(include="all") -> count, mean, std deviation, min, 25%, 50%, 75%, max
# all -> UNIQUE, top, freq
#
# df.info()

# %% [markdown]
# ### Data lab
#
# <ul>
#     <li>Data source: <a href="https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDA0101ENSkillsNetwork20235326-2021-01-01" target="_blank">https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data</a></li>
#     <li>Data type: csv</li>
# </ul>

# %%
#install specific version of libraries used in  lab
import sys
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install scipy
# !{sys.executable} -m pip install seaborn
# !{sys.executable} -m pip install ipywidgets
# !{sys.executable} -m pip install tqdm
# Out:
# Requirement already satisfied: pandas in /home/flynn/anaconda3/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/flynn/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/flynn/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /home/flynn/anaconda3/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /home/flynn/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in /home/flynn/anaconda3/lib/python3.9/site-packages (1.21.5)
# Requirement already satisfied: matplotlib in /home/flynn/anaconda3/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/flynn/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: numpy>=1.17 in /home/flynn/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: fonttools>=4.22.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/flynn/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/flynn/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in /home/flynn/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in /home/flynn/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scipy in /home/flynn/anaconda3/lib/python3.9/site-packages (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /home/flynn/anaconda3/lib/python3.9/site-packages (from scipy) (1.21.5)
# Requirement already satisfied: seaborn in /home/flynn/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in /home/flynn/anaconda3/lib/python3.9/site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: pandas>=0.23 in /home/flynn/anaconda3/lib/python3.9/site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: scipy>=1.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: matplotlib>=2.2 in /home/flynn/anaconda3/lib/python3.9/site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: cycler>=0.10 in /home/flynn/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/flynn/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/flynn/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/flynn/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in /home/flynn/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/flynn/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: ipywidgets in /home/flynn/anaconda3/lib/python3.9/site-packages (7.6.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipywidgets) (8.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipywidgets) (5.3.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipywidgets) (6.9.1)
# Requirement already satisfied: traitlets>=4.3.1 in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: nest-asyncio in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.5)
# Requirement already satisfied: tornado<7.0,>=4.2 in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: jedi>=0.16 in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: backcall in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.20)
# Requirement already satisfied: pickleshare in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (2.11.2)
# Requirement already satisfied: pexpect>4.3 in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (61.2.0)
# Requirement already satisfied: stack-data in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /home/flynn/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pyzmq>=13 in /home/flynn/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.1 in /home/flynn/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: fastjsonschema in /home/flynn/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/flynn/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets) (4.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (0.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/flynn/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/flynn/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.5 in /home/flynn/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /home/flynn/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.8)
# Requirement already satisfied: terminado>=0.8.3 in /home/flynn/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: jinja2 in /home/flynn/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.11.3)
# Requirement already satisfied: nbconvert in /home/flynn/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.4.4)
# Requirement already satisfied: argon2-cffi in /home/flynn/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3.0)
# Requirement already satisfied: prometheus-client in /home/flynn/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.13.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/flynn/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/flynn/anaconda3/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.15.0)
# Requirement already satisfied: pycparser in /home/flynn/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/flynn/anaconda3/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.1)
# Requirement already satisfied: defusedxml in /home/flynn/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /home/flynn/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.11.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/flynn/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/flynn/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/flynn/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.13)
# Requirement already satisfied: testpath in /home/flynn/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in /home/flynn/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/flynn/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.4)
# Requirement already satisfied: bleach in /home/flynn/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.1.0)
# Requirement already satisfied: soupsieve>1.2 in /home/flynn/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.3.1)
# Requirement already satisfied: webencodings in /home/flynn/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: packaging in /home/flynn/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/flynn/anaconda3/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.4)
# Requirement already satisfied: executing in /home/flynn/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in /home/flynn/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in /home/flynn/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: tqdm in /home/flynn/anaconda3/lib/python3.9/site-packages (4.64.0)

# %%
# Out:
#   Input In [13]
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %%
# import pandas library
import pandas as pd
import numpy as np

# %%
#This function will download the dataset into your browser 

from pyodide.http import pyfetch

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [12], in <cell line: 3>()
#       1 #This function will download the dataset into your browser
# ----> 3 from pyodide.http import pyfetch
#       5 async def download(url, filename):
#       6     response = await pyfetch(url)
#
# ModuleNotFoundError: No module named 'pyodide'

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We use <code>pandas.read_csv()</code> function to read the csv file. In the brackets, we put the file path along with a quotation mark so that pandas will read the file into a dataframe from that address. The file path can be either an URL or your local file address.<br>
#
# Because the data does not include headers, we can add an argument <code>headers = None</code> inside the <code>read_csv()</code> method so that pandas will not automatically set the first row as a header.<br>
#
# You can also assign the dataset to any variable you create.
#
# </p>

# %%
path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"

# %%
#you will need to download the dataset; if you are running locally, please comment out the following 
await download(path, "auto.csv")
path="auto.csv"

# %% [markdown]
# This dataset was hosted on IBM Cloud object. Click <a href="https://cocl.us/DA101EN_object_storage?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDA0101ENSkillsNetwork20235326-2021-01-01">HERE</a> for free storage.

# %% [markdown]
# # Import pandas library
# import pandas as pd
#
# # Read the online file by the URL provides above, and assign it to variable "df"
#
# df = pd.read_csv(path, header=None)

# %% [markdown]
# After reading the dataset, we can use the <code>dataframe.head(n)</code> method to check the top n rows of the dataframe, where n is an integer. Contrary to <code>dataframe.head(n)</code>, <code>dataframe.tail(n)</code> will show you the bottom n rows of the dataframe.

# %%
# show the first 5 rows using dataframe.head() method
print("The first 5 rows of the dataframe") 
df.head(5)

# %%
print("The last 10 rows of the dataframe\n")
df.tail(10)

# %%
# create headers list
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
print("headers\n", headers)

# %%
df.columns = headers
df.head(10)

# %%
df1=df.replace('?',np.NaN)

# %%
df=df1.dropna(subset=["price"], axis=0)
df.head(20)

# %%
print(df.columns)

# %% [markdown]
# <h2>Save Dataset</h2>
# <p>
# Correspondingly, Pandas enables us to save the dataset to csv. By using the <code>dataframe.to_csv()</code> method, you can add the file path and name along with quotation marks in the brackets.
# </p>
# <p>
# For example, if you would save the dataframe <b>df</b> as <b>automobile.csv</b> to your local machine, you may use the syntax below, where <code>index = False</code> means the row names will not be written.
# </p>

# %%
df.to_csv("automobile.csv", index=False)

# %% [markdown]
# <h2>Read/Save Other Data Formats</h2>
#
# | Data Formate |        Read       |            Save |
# | ------------ | :---------------: | --------------: |
# | csv          |  `pd.read_csv()`  |   `df.to_csv()` |
# | json         |  `pd.read_json()` |  `df.to_json()` |
# | excel        | `pd.read_excel()` | `df.to_excel()` |
# | hdf          |  `pd.read_hdf()`  |   `df.to_hdf()` |
# | sql          |  `pd.read_sql()`  |   `df.to_sql()` |
# | ...          |        ...        |             ... |

# %%
df.dtypes

# %%
# check the data type of data frame "df" by .dtypes
print(df.dtypes)

# %%
dataframe.describe()

# %%
df.describe()

# %%
# describe all the columns in "df" 
df.describe(include = "all")

# %%
df[['length', 'compression-ratio']].describe()

# %%
dataframe.info()

# %%
# look at the info of "df"
df.info()

# %% [markdown]
# ![curso5.PNG](attachment:curso5.PNG)

# %% [markdown]
# ![curso6.PNG](attachment:curso6.PNG)

# %% [markdown]
# ![curso7.PNG](attachment:curso7.PNG)

# %% [markdown]
# # Module 2 - Cleaning and Preparing the Data
#
# Pre-Processing Data in Python.- convert raw to for another data.
#
# - identify and handling missing value
# - data formatting
# - Data normalization
# - Data Binning
# - Turning categorical values to numerical values
#
# ## Dealing with a nmissing value
# ? "N/A", 0
# - check with the data collection source
#
# - Drop the missing values: drop variable or data entry
#
# - replace the missing values: with average. by frequency. based on other functions.
#
# dataframes.dropna() axis 0 the entire row, 1 drops the entire column, implace true writes the result back
#
# #### Replace missing values
# ![curso8.PNG](attachment:curso8.PNG)

# %% [markdown]
# ![curso9.PNG](attachment:curso9.PNG)

# %% [markdown]
# ![curso10.PNG](attachment:curso10.PNG)

# %% [markdown]
# ![curso11.PNG](attachment:curso11.PNG)

# %% [markdown]
# ![curso12.PNG](attachment:curso12.PNG)

# %% [markdown]
# ![curso13.PNG](attachment:curso13.PNG)

# %% [markdown]
# ![curso14.PNG](attachment:curso14.PNG)

# %% [markdown]
# ![curso15.PNG](attachment:curso15.PNG)

# %% [markdown]
# ![curso16.PNG](attachment:curso16.PNG)

# %% [markdown]
# ![curso17.PNG](attachment:curso17.PNG)

# %% [markdown]
# ![curso18.PNG](attachment:curso18.PNG)

# %% [markdown]
# # LAB

# %% [markdown]
# <h1> Question  #1: </h1>
#
# <b>Based on the example above, replace NaN in "stroke" column with the mean value.</b>

# %% [markdown]
# avg_stroke = df["stroke"].astype("float").mean(axis = 0)
# print("Average of stroke:", avg_stroke)
#
# df["stroke"].replace(np.nan, avg_stroke, inplace = True)

# %% [markdown]
# Calculate the mean value for the "horsepower" column

# %% [markdown]
# Question #2:
#
# According to the example above, transform mpg to L/100km in the column of "highway-mpg" and change the name of column to "highway-L/100km".

# %% [markdown]
# df["highway-mpg"] = 235/df["highway-mpg"]
#
# df.rename(columns={'highway-mpg':'highway-L/100km'}, inplace=True)
#
# df.head()

# %% [markdown]
# <h1> Question #3: </h1>
#
# <b>According to the example above, normalize the column "height".</b>

# %% [markdown]
# df['height'] = df['height']/df['height'].max()
#
# df[["length","width","height"]].head()

# %% [markdown]
# <h1> Question  #4: </h1>
#
# <b>Similar to before, create an indicator variable for the column "aspiration"</b>
# dummy_variable_2 = pd.get_dummies(df['aspiration'])
#
# dummy_variable_2.rename(columns={'std':'aspiration-std', 'turbo': 'aspiration-turbo'}, inplace=True)
#
# dummy_variable_2.head()

# %% [markdown]
# <h1> Question  #5: </h1>
#
# <b>Merge the new dataframe to the original dataframe, then drop the column 'aspiration'.</b>

# %% [markdown]
# df = pd.concat([df, dummy_variable_2], axis=1)
#
# df.drop('aspiration', axis = 1, inplace=True)

# %% [markdown]
# ![curso19.PNG](attachment:curso19.PNG)

# %% [markdown]
# ![curso20.PNG](attachment:curso20.PNG)

# %% [markdown]
# ![curso21.PNG](attachment:curso21.PNG)
